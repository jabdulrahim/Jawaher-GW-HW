# %%
# !pip install simple_salesforce
# Out:
# Requirement already satisfied: simple_salesforce in c:\users\jawah\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: authlib in c:\users\jawah\anaconda3\lib\site-packages (from simple_salesforce) (0.14.3)
# Requirement already satisfied: requests>=2.22.0 in c:\users\jawah\anaconda3\lib\site-packages (from simple_salesforce) (2.22.0)
# Requirement already satisfied: cryptography in c:\users\jawah\anaconda3\lib\site-packages (from authlib->simple_salesforce) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jawah\anaconda3\lib\site-packages (from requests>=2.22.0->simple_salesforce) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jawah\anaconda3\lib\site-packages (from requests>=2.22.0->simple_salesforce) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jawah\anaconda3\lib\site-packages (from requests>=2.22.0->simple_salesforce) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jawah\anaconda3\lib\site-packages (from requests>=2.22.0->simple_salesforce) (1.25.8)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\jawah\anaconda3\lib\site-packages (from cryptography->authlib->simple_salesforce) (1.14.0)
# Requirement already satisfied: six>=1.4.1 in c:\users\jawah\anaconda3\lib\site-packages (from cryptography->authlib->simple_salesforce) (1.14.0)
# Requirement already satisfied: pycparser in c:\users\jawah\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography->authlib->simple_salesforce) (2.19)

# %%
import json
from sqlalchemy import create_engine
from datetime import date
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()

# %%
from config import sf_username, sf_password, sf_security_token
from config import remote_db_endpoint, remote_db_port
from config import remote_db_name, remote_db_user, remote_db_pwd

# %%
from simple_salesforce import Salesforce
sf = Salesforce(username=sf_username, password=sf_password, security_token=sf_security_token)

# %%
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %%
#Student
student_data_df = pd.read_sql("SELECT * FROM student", conn)
student_data_df.head(5)
# Out:
#    ID_Student StudentID    LastName  FirstName MiddleName BirthDate Gender
# 0          33  25004961       Moore    Heather      Alice      None      F
# 1          34  25003514      Multak      Ilana    Cecille      None      F
# 2          35  25005833     Murillo    Jessica    Dorothy      None      F
# 3          36  25002589  Romanowski     Kandra  Genevieve      None      F
# 4          37  25007185      Hoffer  Katherine   Lynnette      None      F

# %%
student_data_records = student_data_df.to_dict('records')
student_data_records
# Out:
# [{'ID_Student': 33,
#   'StudentID': '25004961',
#   'LastName': 'Moore',
#   'FirstName': 'Heather',
#   'MiddleName': 'Alice',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 34,
#   'StudentID': '25003514',
#   'LastName': 'Multak',
#   'FirstName': 'Ilana',
#   'MiddleName': 'Cecille',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 35,
#   'StudentID': '25005833',
#   'LastName': 'Murillo',
#   'FirstName': 'Jessica',
#   'MiddleName': 'Dorothy',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 36,
#   'StudentID': '25002589',
#   'LastName': 'Romanowski',
#   'FirstName': 'Kandra',
#   'MiddleName': 'Genevieve',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 37,
#   'StudentID': '25007185',
#   'LastName': 'Hoffer',
#   'FirstName': 'Katherine',
#   'MiddleName': 'Lynnette',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 38,
#   'StudentID': '25006014',
#   'LastName': 'Poocharoen',
#   'FirstName': 'Pariya',
#   'MiddleName': 'Mariette',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 39,
#   'StudentID': '25007528',
#   'LastName': 'Mantrala',
#   'FirstName': 'Sriharitha',
#   'MiddleName': 'Patty',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 40,
#   'StudentID': '25003778',
#   'LastName': 'Kelly',
#   'FirstName': 'Carly',
#   'MiddleName': 'Raelene',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 41,
#   'StudentID': '25003605',
#   'LastName': 'Sraha',
#   'FirstName': 'Clementine',
#   'MiddleName': 'Kendall',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 42,
#   'StudentID': '25002056',
#   'LastName': 'Abdulrahim',
#   'FirstName': 'Jawaher',
#   'MiddleName': 'Angela',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 43,
#   'StudentID': '25004152',
#   'LastName': 'Schulte',
#   'FirstName': 'Sarah',
#   'MiddleName': 'Serita',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 44,
#   'StudentID': '25004097',
#   'LastName': 'Damdinsuren',
#   'FirstName': 'Undraa',
#   'MiddleName': 'Claire',
#   'BirthDate': None,
#   'Gender': 'F'},
#  {'ID_Student': 45,
#   'StudentID': '25002311',
#   'LastName': 'Smith',
#   'FirstName': 'James',
#   'MiddleName': 'Carlton',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 46,
#   'StudentID': '25005602',
#   'LastName': 'Martinez',
#   'FirstName': 'Joisel',
#   'MiddleName': 'Cyrus',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 47,
#   'StudentID': '25006805',
#   'LastName': 'Odhiambo',
#   'FirstName': 'Pius',
#   'MiddleName': 'Danny',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 48,
#   'StudentID': '25006947',
#   'LastName': 'Karr',
#   'FirstName': 'Todd',
#   'MiddleName': 'Darren',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 49,
#   'StudentID': '25002714',
#   'LastName': 'Stark',
#   'FirstName': 'Tom',
#   'MiddleName': 'Deangelo',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 50,
#   'StudentID': '25005284',
#   'LastName': 'Mahmood',
#   'FirstName': 'Adit',
#   'MiddleName': 'Dion',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 51,
#   'StudentID': '25006348',
#   'LastName': 'Mikus',
#   'FirstName': 'Chris',
#   'MiddleName': 'Floyd',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 52,
#   'StudentID': '25002555',
#   'LastName': 'Hanafin',
#   'FirstName': 'Christopher',
#   'MiddleName': 'Horace',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 53,
#   'StudentID': '25005250',
#   'LastName': 'Fingerut',
#   'FirstName': 'Cole',
#   'MiddleName': 'Lino',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 54,
#   'StudentID': '25002325',
#   'LastName': 'Hoff',
#   'FirstName': 'David',
#   'MiddleName': 'Lucien',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 55,
#   'StudentID': '25003773',
#   'LastName': 'Molina',
#   'FirstName': 'Dino',
#   'MiddleName': 'Lynwood',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 56,
#   'StudentID': '25003936',
#   'LastName': 'Vega',
#   'FirstName': 'John',
#   'MiddleName': 'Noelle',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 57,
#   'StudentID': '25005443',
#   'LastName': 'Clarke',
#   'FirstName': 'Michael',
#   'MiddleName': 'Parker',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 58,
#   'StudentID': '25006762',
#   'LastName': 'Huynh',
#   'FirstName': 'Patrick',
#   'MiddleName': 'Richard',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 59,
#   'StudentID': '25006027',
#   'LastName': 'Oppan',
#   'FirstName': 'Robert',
#   'MiddleName': 'Riley',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 60,
#   'StudentID': '25002876',
#   'LastName': 'Doucet',
#   'FirstName': 'Trevor',
#   'MiddleName': 'Seth',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 61,
#   'StudentID': '25007333',
#   'LastName': 'Omar',
#   'FirstName': 'Yasir',
#   'MiddleName': 'Solomon',
#   'BirthDate': None,
#   'Gender': 'M'},
#  {'ID_Student': 62,
#   'StudentID': '25007334',
#   'LastName': 'Williamson',
#   'FirstName': 'Kevin',
#   'MiddleName': 'Stewart',
#   'BirthDate': None,
#   'Gender': 'M'}]

# %%
for rec in student_data_records:

    record = {
        'ID_Student__c': rec['ID_Student'],
        'StudentID__c': rec['StudentID'],
        'LastName__c': rec['LastName'],
        'FirstName__c': rec['FirstName'],
        'MiddleName__c': rec['MiddleName'],
        'BirthDate__c': rec['BirthDate'],
        'Gender__c': rec['Gender']
    }
    
    try:
        sf.Student__c.create(record)
    except Exception as e:
        print(e)

# %%
student_lookup_list = []

data = sf.query_all_iter("SELECT ID_Student__c, Name FROM Student__c")
for row in data:
    rec = {
        'ID_Student': row['ID_Student__c'],
        'StudentSF': row['Name']
    }
    student_lookup_list.append(rec)

# %%
student_lookup_df = pd.DataFrame(student_lookup_list)
student_lookup_df.head(5)
# Out:
#    ID_Student        StudentSF
# 0        37.0  a093h000000kB7r
# 1        53.0  a093h000000kB99
# 2        33.0  a093h000000kB7X
# 3        45.0  a093h000000kB8V
# 4        60.0  a093h000000kB9i

# %%
class_lookup_list = []

data = sf.query_all_iter("SELECT ID_Class__c, Name FROM Class__c")
for row in data:
    rec = {
        'ID_Class': row['ID_Class__c'],
        'ClassSF': row['Name']
    }
    class_lookup_list.append(rec)

# %%
class_lookup_df = pd.DataFrame(class_lookup_list)
class_lookup_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Classparticipant
query = '''
    SELECT
        cp.*
        
    FROM
        classparticipant cp
        
'''
classparticipant_data_df = pd.read_sql(query, conn)
classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class   StartDate EndDate
# 0                    1          33         1  2020-03-16    None
# 1                    2          34         1  2020-03-16    None
# 2                    3          35         1  2020-03-16    None
# 3                    4          62         1  2020-03-16    None
# 4                    5          36         1  2020-03-16    None

# %%
classparticipant_data_df = pd.merge(classparticipant_data_df, student_lookup_df, how='left')
classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class   StartDate EndDate  \
# 0                    1          33         1  2020-03-16    None
# 1                    2          34         1  2020-03-16    None
# 2                    3          35         1  2020-03-16    None
# 3                    4          62         1  2020-03-16    None
# 4                    5          36         1  2020-03-16    None
#
#          StudentSF
# 0  a093h000000kB7X
# 1  a093h000000kB7c
# 2  a093h000000kB7h
# 3  a093h000000kB9s
# 4  a093h000000kB7m

# %%
classparticipant_data_df = pd.merge(classparticipant_data_df, class_lookup_df, how='left')
classparticipant_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-16-c9c9b3317d38> in <module>
# ----> 1 classparticipant_data_df = pd.merge(classparticipant_data_df, class_lookup_df, how='left')
#       2 classparticipant_data_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     618             warnings.warn(msg, UserWarning)
#     619
# --> 620         self._validate_specification()
#     621
#     622         # note this function has side effects
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1196                             ron=self.right_on,
#    1197                             lidx=self.left_index,
# -> 1198                             ridx=self.right_index,
#    1199                         )
#    1200                     )
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
classparticipant_data_records = classparticipant_data_df.to_dict(orient='records')
classparticipant_data_records
# Out:
# [{'ID_ClassParticipant': 1,
#   'ID_Student': 33,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB7X'},
#  {'ID_ClassParticipant': 2,
#   'ID_Student': 34,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB7c'},
#  {'ID_ClassParticipant': 3,
#   'ID_Student': 35,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB7h'},
#  {'ID_ClassParticipant': 4,
#   'ID_Student': 62,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9s'},
#  {'ID_ClassParticipant': 5,
#   'ID_Student': 36,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB7m'},
#  {'ID_ClassParticipant': 6,
#   'ID_Student': 37,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB7r'},
#  {'ID_ClassParticipant': 7,
#   'ID_Student': 38,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB7w'},
#  {'ID_ClassParticipant': 8,
#   'ID_Student': 39,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB81'},
#  {'ID_ClassParticipant': 9,
#   'ID_Student': 40,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB86'},
#  {'ID_ClassParticipant': 10,
#   'ID_Student': 41,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8B'},
#  {'ID_ClassParticipant': 11,
#   'ID_Student': 42,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8G'},
#  {'ID_ClassParticipant': 12,
#   'ID_Student': 43,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8L'},
#  {'ID_ClassParticipant': 13,
#   'ID_Student': 46,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8a'},
#  {'ID_ClassParticipant': 14,
#   'ID_Student': 47,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8f'},
#  {'ID_ClassParticipant': 15,
#   'ID_Student': 48,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8k'},
#  {'ID_ClassParticipant': 16,
#   'ID_Student': 49,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8p'},
#  {'ID_ClassParticipant': 17,
#   'ID_Student': 50,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8u'},
#  {'ID_ClassParticipant': 18,
#   'ID_Student': 51,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8z'},
#  {'ID_ClassParticipant': 20,
#   'ID_Student': 53,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB99'},
#  {'ID_ClassParticipant': 21,
#   'ID_Student': 54,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9E'},
#  {'ID_ClassParticipant': 22,
#   'ID_Student': 55,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9J'},
#  {'ID_ClassParticipant': 23,
#   'ID_Student': 56,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9O'},
#  {'ID_ClassParticipant': 24,
#   'ID_Student': 57,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9T'},
#  {'ID_ClassParticipant': 25,
#   'ID_Student': 58,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9Y'},
#  {'ID_ClassParticipant': 26,
#   'ID_Student': 59,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9d'},
#  {'ID_ClassParticipant': 27,
#   'ID_Student': 60,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9i'},
#  {'ID_ClassParticipant': 28,
#   'ID_Student': 61,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB9n'},
#  {'ID_ClassParticipant': 29,
#   'ID_Student': 44,
#   'ID_Class': 1,
#   'StartDate': datetime.date(2020, 3, 16),
#   'EndDate': None,
#   'StudentSF': 'a093h000000kB8Q'}]

# %%
for rec in classparticipant_data_records:
 
    record = {
        'ID_ClassParticipant__c': rec['ID_ClassParticipant'],
        'ID_Student__c': rec['ID_Student'],
        'ID_Class__c': rec['ID_Class'],
        'StartDate__c': rec['StartDate'].isoformat(),
        'EndDate__c': rec['EndDate'],
        'Student_Name__c': rec['StudentSF'],
        'Class_Name__c': rec['ClassSF']
    }
    
    try:
        sf.Class_Participant__c.create(record)
    except Exception as e:
        print(e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-2bf3cdd0d912> in <module>
#       8         'EndDate__c': rec['EndDate'],
#       9         'Student_Name__c': rec['StudentSF'],
# ---> 10         'Class_Name__c': rec['ClassSF']
#      11     }
#      12
#
# KeyError: 'ClassSF'
